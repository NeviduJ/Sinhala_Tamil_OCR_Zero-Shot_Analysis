# %%
import pandas as pd
from collections import defaultdict

# %%
def analyze_ocr_summary(file_path):
    """
    Analyzes OCR text extraction errors from a CSV file and provides a summary.

    Args:
        file_path (str): The path to the CSV file.
    """
    try:
        df = pd.read_csv(file_path)
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
        return

    if 'reference' not in df.columns or 'generated' not in df.columns:
        print("Error: The CSV file must contain 'reference' and 'generated' columns.")
        return

    # To store incorrect transformations: {'actual_char': {'incorrect_char': count}}
    error_counts = defaultdict(lambda: defaultdict(int))
    total_misidentifications = 0

    for index, row in df.iterrows():
        reference_text = str(row['reference'])
        generated_text = str(row['generated'])

        # Iterate through the strings up to the length of the shorter string
        for i in range(min(len(reference_text), len(generated_text))):
            if reference_text[i] != generated_text[i]:
                error_counts[reference_text[i]][generated_text[i]] += 1
                total_misidentifications += 1
        
        # Handle cases where lengths are different (missing or extra characters)
        if len(reference_text) > len(generated_text):
            # Characters present in reference but missing in generated
            for i in range(len(generated_text), len(reference_text)):
                error_counts[reference_text[i]]['<MISSING>'] += 1
                total_misidentifications += 1
        elif len(generated_text) > len(reference_text):
            # Extra characters in generated (not present in reference)
            for i in range(len(reference_text), len(generated_text)):
                error_counts['<EXTRA>'][generated_text[i]] += 1
                total_misidentifications += 1


    print(f"Total Number of Misidentifications: {total_misidentifications}")
    print("\nMost Erroneous Characters (based on total errors):")
    print("-" * 50)

    if not error_counts and total_misidentifications == 0:
        print("No character mismatches found.")
        return

    overall_problematic_chars = defaultdict(int)
    for ref_char, errors in error_counts.items():
        if ref_char == '<EXTRA>':
            # Sum up errors for extra characters, categorize by the extra char itself
            for gen_char, count in errors.items():
                overall_problematic_chars[f"EXTRA:'{gen_char}'"] += count
        else:
            for count in errors.values():
                overall_problematic_chars[ref_char] += count
    
    sorted_problematic = sorted(overall_problematic_chars.items(), key=lambda item: item[1], reverse=True)
    
    for char, total_errors in sorted_problematic:
        print(f"Character '{char}': {total_errors} errors")

# %%
analyze_ocr_summary('Surya_OCR_Results.csv')
# Out:
# Total Number of Misidentifications: 127225
#
# Most Erroneous Characters (based on total errors):
# --------------------------------------------------
# Character ' ': 17298 errors
# Character '්': 9520 errors
# Character 'ි': 7181 errors
# Character 'න': 6686 errors
# Character 'ර': 6164 errors
# Character 'ය': 5864 errors
# Character 'ා': 5661 errors
# Character 'ව': 5412 errors
# Character 'ක': 5358 errors
# Character 'ම': 4569 errors
# Character 'ත': 4420 errors
# Character 'ස': 3440 errors
# Character 'ු': 3412 errors
# Character 'ල': 2921 errors
# Character 'ද': 2752 errors
# Character 'ප': 2727 errors
# Character 'ේ': 2546 errors
# Character 'ෙ': 2271 errors
# Character 'ට': 2121 errors
# Character 'හ': 2065 errors
# Character 'ී': 1898 errors
# Character 'ග': 1761 errors
# Character 'ැ': 1365 errors
# Character 'අ': 1109 errors
# Character 'බ': 1108 errors
# Character '.': 857 errors
# Character 'ො': 791 errors
# Character 'ණ': 781 errors
# Character 'ශ': 751 errors
# Character 'ං': 727 errors
# Character 'ඩ': 650 errors
# Character 'ජ': 632 errors
# Character 'ධ': 590 errors
# Character 'ළ': 536 errors
# Character ',': 517 errors
# Character 'එ': 487 errors
# Character 'EXTRA:'්'': 473 errors
# Character 'ෝ': 452 errors
# Character 'ූ': 446 errors
# Character 'ෂ': 421 errors
# Character 'ඇ': 328 errors
# Character 'ඉ': 305 errors
# Character 'ච': 279 errors
# Character 'ආ': 279 errors
# Character 'ඳ': 241 errors
# Character 'භ': 241 errors
# Character 'EXTRA:'ා'': 231 errors
# Character 'EXTRA:'ය'': 227 errors
# Character '‌': 218 errors
# Character 'EXTRA:'න'': 212 errors
# Character 'ඔ': 195 errors
# Character 'EXTRA:'ි'': 191 errors
# Character 'EXTRA:'ේ'': 191 errors
# Character 'ථ': 171 errors
# Character 'ඒ': 170 errors
# Character 'EXTRA:'ක'': 168 errors
# Character 'උ': 163 errors
# Character '1': 162 errors
# Character 'EXTRA:'.'': 158 errors
# Character 'EXTRA:'-'': 153 errors
# Character 'EXTRA:'ම'': 150 errors
# Character 'EXTRA:'ට'': 149 errors
# Character 'EXTRA:'ව'': 141 errors
# Character 'ෑ': 138 errors
# Character '0': 138 errors
# Character 'EXTRA:'ු'': 133 errors
# Character '2': 127 errors
# Character 'EXTRA:'ර'': 113 errors
# Character 'ෘ': 101 errors
# Character 'EXTRA:'ත'': 100 errors
# Character '‍': 81 errors
# Character 'EXTRA:'ී'': 77 errors
# Character '-': 73 errors
# Character 'EXTRA:'ල'': 72 errors
# Character 'ඟ': 67 errors
# Character '5': 65 errors
# Character '3': 64 errors
# Character 'ඊ': 61 errors
# Character 'EXTRA:'ද'': 57 errors
# Character '"': 56 errors
# Character '…': 56 errors
# Character 'EXTRA:','': 54 errors
# Character 'EXTRA:'ස'': 54 errors
# Character '4': 53 errors
# Character ''': 53 errors
# Character 'ඹ': 50 errors
# Character '(': 49 errors
# Character 'ඛ': 48 errors
# Character '8': 47 errors
# Character 'EXTRA:' '': 45 errors
# Character '9': 44 errors
# Character '?': 44 errors
# Character 'ෆ': 44 errors
# Character ')': 43 errors
# Character 'EXTRA:'හ'': 41 errors
# Character '7': 41 errors
# Character '/': 41 errors
# Character '6': 40 errors
# Character 'ඨ': 40 errors
# Character 'ඥ': 39 errors
# Character '_': 38 errors
# Character 'ඕ': 37 errors
# Character 'ෛ': 34 errors
# Character '்': 34 errors
# Character 'EXTRA:'‍'': 32 errors
# Character '”': 32 errors
# Character 'EXTRA:'ෙ'': 31 errors
# Character ':': 31 errors
# Character '‘': 31 errors
# Character 'EXTRA:'ණ'': 30 errors
# Character 'ඡ': 28 errors
# Character 'ෞ': 28 errors
# Character 'EXTRA:'ග'': 26 errors
# Character '!': 24 errors
# Character '“': 24 errors
# Character 'ி': 23 errors
# Character 'ඝ': 22 errors
# Character 'ඵ': 21 errors
# Character 'EXTRA:'ළ'': 19 errors
# Character '’': 19 errors
# Character 'EXTRA:'බ'': 18 errors
# Character 'EXTRA:'ශ'': 17 errors
# Character 'EXTRA:'ඩ'': 17 errors
# Character 'த': 17 errors
# Character 'EXTRA:'ඒ'': 16 errors
# Character 'EXTRA:'ූ'': 15 errors
# Character '@': 15 errors
# Character 'EXTRA:'ප'': 14 errors
# Character 'EXTRA:'ධ'': 13 errors
# Character 'EXTRA:')'': 12 errors
# Character 'EXTRA:'ෂ'': 12 errors
# Character 'EXTRA:'ං'': 12 errors
# Character '–': 12 errors
# Character ';': 12 errors
# Character 'ඈ': 12 errors
# Character 'ர': 12 errors
# Character 'EXTRA:'''': 11 errors
# Character 'EXTRA:'1'': 11 errors
# Character 'EXTRA:'එ'': 11 errors
# Character 'EXTRA:'ෝ'': 11 errors
# Character '&': 11 errors
# Character 'ඬ': 10 errors
# Character '©': 10 errors
# Character 'ு': 10 errors
# Character 'ள': 10 errors
# Character 'ல': 10 errors
# Character 'EXTRA:'ැ'': 9 errors
# Character 'வ': 9 errors
# Character 'க': 9 errors
# Character 'EXTRA:'('': 8 errors
# Character 'EXTRA:'ඳ'': 8 errors
# Character 'EXTRA:'ො'': 8 errors
# Character '´': 8 errors
# Character 'ا': 8 errors
# Character 'ඌ': 8 errors
# Character 'ய': 8 errors
# Character '\': 8 errors
# Character 'EXTRA:'ජ'': 7 errors
# Character 'EXTRA:'ථ'': 7 errors
# Character '*': 7 errors
# Character 'ඓ': 7 errors
# Character 'ل': 7 errors
# Character 'ன': 7 errors
# Character 'ச': 7 errors
# Character 'ை': 7 errors
# Character 'EXTRA:'0'': 6 errors
# Character 'EXTRA:'අ'': 6 errors
# Character 'EXTRA:'?'': 6 errors
# Character 'ந': 6 errors
# Character 'ம': 6 errors
# Character '⇒': 6 errors
# Character '»': 6 errors
# Character '⁣': 6 errors
# Character 'EXTRA:'ඹ'': 5 errors
# Character 'EXTRA:'3'': 5 errors
# Character 'EXTRA:'භ'': 5 errors
# Character 'ඞ': 5 errors
# Character 'م': 5 errors
# Character 'ற': 5 errors
# Character 'ப': 5 errors
# Character 'ா': 5 errors
# Character 'ே': 5 errors
# Character 'EXTRA:'2'': 4 errors
# Character 'EXTRA:'ඟ'': 4 errors
# Character 'و': 4 errors
# Character 'س': 4 errors
# Character 'ட': 4 errors
# Character 'இ': 4 errors
# Character 'ඤ': 4 errors
# Character 'EXTRA:'4'': 3 errors
# Character 'EXTRA:'6'': 3 errors
# Character 'EXTRA:'’'': 3 errors
# Character 'EXTRA:'ෑ'': 3 errors
# Character '`': 3 errors
# Character '﻿': 3 errors
# Character ']': 3 errors
# Character 'ෟ': 3 errors
# Character 'ඖ': 3 errors
# Character '«': 3 errors
# Character '‼': 3 errors
# Character 'ோ': 3 errors
# Character 'உ': 3 errors
# Character '%': 3 errors
# Character '¿': 3 errors
# Character '=': 3 errors
# Character '​': 3 errors
# Character 'EXTRA:'"'': 2 errors
# Character 'EXTRA:'7'': 2 errors
# Character 'EXTRA:'ඇ'': 2 errors
# Character 'EXTRA:'”'': 2 errors
# Character '—': 2 errors
# Character '[': 2 errors
# Character 'ج': 2 errors
# Character 'ح': 2 errors
# Character 'ب': 2 errors
# Character 'ي': 2 errors
# Character 'د': 2 errors
# Character 'ن': 2 errors
# Character 'ங': 2 errors
# Character '🌴': 2 errors
# Character 'ඪ': 2 errors
# Character 'ඃ': 2 errors
# Character 'ண': 2 errors
# Character 'ஷ': 2 errors
# Character 'ொ': 2 errors
# Character '+': 2 errors
# Character '$': 2 errors
# Character '~': 2 errors
# Character '■': 2 errors
# Character '•': 2 errors
# Character '‛': 2 errors
# Character 'EXTRA:']'': 1 errors
# Character 'EXTRA:'ෞ'': 1 errors
# Character 'EXTRA:'ඉ'': 1 errors
# Character 'EXTRA:'ඡ'': 1 errors
# Character 'EXTRA:'5'': 1 errors
# Character 'EXTRA:'ආ'': 1 errors
# Character 'EXTRA:':'': 1 errors
# Character 'EXTRA:'/'': 1 errors
# Character 'EXTRA:'ඝ'': 1 errors
# Character 'EXTRA:'උ'': 1 errors
# Character 'EXTRA:'ඥ'': 1 errors
# Character 'EXTRA:'ඊ'': 1 errors
# Character 'EXTRA:'–'': 1 errors
# Character 'EXTRA:'ෆ'': 1 errors
# Character 'EXTRA:'ඛ'': 1 errors
# Character '': 1 errors
# Character 'µ': 1 errors
# Character '¾': 1 errors
# Character 'é': 1 errors
# Character 'ö': 1 errors
# Character 'ه': 1 errors
# Character 'ص': 1 errors
# Character 'ش': 1 errors
# Character 'خ': 1 errors
# Character 'ك': 1 errors
# Character 'ت': 1 errors
# Character 'ر': 1 errors
# Character 'ط': 1 errors
# Character 'ق': 1 errors
# Character 'ع': 1 errors
# Character 'ض': 1 errors
# Character '♦': 1 errors
# Character 'ழ': 1 errors
# Character 'ஞ': 1 errors
# Character '🌲': 1 errors
# Character '🌸': 1 errors
# Character '📲': 1 errors
# Character '🌺': 1 errors
# Character 'ஆ': 1 errors
# Character '': 1 errors
# Character '▶': 1 errors
# Character '�': 1 errors
# Character 'ෲ': 1 errors
# Character '↑': 1 errors
# Character 'ீ': 1 errors
# Character '、': 1 errors
# Character '˝': 1 errors
# Character 'ñ': 1 errors
# Character '·': 1 errors
