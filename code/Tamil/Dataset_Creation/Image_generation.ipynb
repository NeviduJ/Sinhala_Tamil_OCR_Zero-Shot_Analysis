# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import re

# %%
# pip install Pillow

# %%
def text_to_dataframe(file_path):
    """
    Reads a text file line by line and puts each line into a pandas DataFrame.

    Args:
        file_path (str): The path to the text file.

    Returns:
        pandas.DataFrame: A DataFrame where each row corresponds to a line
                          from the text file. The DataFrame will have a single
                          column named 'text' containing the lines.
                          Returns None if the file cannot be opened.
    """
    try:
        with open(file_path, 'r') as file:
            tamil_lines = []
            for line in file:
                tamil_only = re.sub(r'[^\u0B80-\u0BFF\s]', ' ', line)
                tamil_only = ' '.join(tamil_only.split()) # Remove multiple spaces
                tamil_lines.append(tamil_only.strip())
        df = pd.DataFrame({'text': tamil_lines})
        return df
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
file_path = '/content/drive/MyDrive/ta.txt'

# %%
df = text_to_dataframe(file_path)

# %%
df.head()
# Out:
#              text
# 0              ரய
# 1            ச சப
# 2       படல்தலப்ப
# 3         ரயல் ரய
# 4  அனத்தபறவகள்இறக

# %%
df.head(20)
# Out:
#                                     text
# 0                                     ரய
# 1                                   ச சப
# 2                              படல்தலப்ப
# 3                                ரயல் ரய
# 4                         அனத்தபறவகள்இறக
# 5   என்ன சய்ய அவர்கள்மகவம்நசக்க றன்அனத்த
# 6              நம்ச றந்தரதம்மற்ற ம்சரப்ப
# 7             அதனல்த ன்நம்கதல் தரவழவ ற்க
# 8         அனத்தமகவம்தளவகந ம்படமடய ம்சய்ய
# 9                        சலச கசங்களபறக்க
# 10               நடனம் இச உணர்வமற்றம்அறவ
# 11    நமக்கக ட்டசறந்தநீங்கள்அதசய்யமடய ம்
# 12                         இங்கஎல்லரம்தீ
# 13                    எழந்தவட க்கஉள்ளச ர
# 14                நடனம் அந்நயர்கள் ஆபத்த
# 15                     மஜக்நடக்கமடய ம்ரய
# 16               ரய அன த்ததன்ன மலம் தன்ன
# 17                  உங்கள் நடனம் தரந்தம்
# 18    நீங்கள் அதகண்டபடக்கமடயவல்லவறஎங்கம்
# 19                           ஆமம் ர ய ரய

# %%
len(df)
# Out:
# 2437960

# %%
df_filtered = df[df['text'].str.len() > 40]

# %%
len(df_filtered)
# Out:
# 222658

# %%
df_filtered.head(20)
# Out:
#                                                   text
# 30   உங்களக்கதர யம் இந்தவ ட்டம ன்கள் நீங்கள் நல்ல இ...
# 55   நன்ப தகக்கப்படவதல் இந்தமந்தர சக்தத றயல் என்ற அ...
# 56         அதஎன்னநம்மவத்த அதனல் கடத்ததடன்மற்றம்சடனஇங்க
# 57          பதநீங்கள்தழர்களவளயஉள்ளன அங்கம டக்கம்உங்கள்
# 72        ஆமம் ந ன்என்னஅறமகம்மற்றம் அசத்தஎன்வல் இறககள்
# 83   நமதநம்பக்ககண்ட இரண்ட அவர்களக ப்பற்றஒன்றகதங்கள்...
# 105     கவலப்படவ ண்டம் தங்கள்இயற்க உணர்வகளஎப்பதம்எடத்த
# 123     எதவம்இல்லஇயற்கஇரப்பத பற்ற தக்கபத வழயல்அறமழவதம்
# 147  ஆனல்ந ன்சய்யமடயத நீங்கள்இந்த என்றல்அதஇல்லசய்யச...
# 150      நம்மீண்டம்வீட்டல்இரக்க ம் மன் ந ம்கட அதத ரயம்
# 164         வரம்ந ளஇரவ அனவரக்கம்இரக்கம்பலஉடயண ந்த என்ற
# 188        நன்ப கறன்அந்த பப்க ண்ட தறந்தப ன்றஒர சடத ப்ப
# 207   பல பறவகள்இங்க மீட்கப்பட்டனர் இரந்தகடத்தல்கரர்கள்
# 249          உங்களக்கதர யம்பலசீஸ் உடன் வளப்படத்தவதல்அத
# 266        ஆனல்வ றம்வதம்பரட்ட நீங்கள் என்ன சய்கறீர்கள்
# 271          அங்கத ன்நன்பகறன் அந்த வஷயம்ந ன்தன்சய்த ன்
# 278     நன்எப்படஎன் இறக கள்பர்க்க ஆனல்ந ன்அந்தவகய னபறவ
# 287  நன்ம கவம்உறத யகஇரக்கற ன்நன்வண்டம் வட்டப்ளஇங்க ...
# 316  சர என்றமனத எனக்ககடத்தக தல் மற்றம்ப சம் கடந்த ஆ...
# 317  அதசமயம்என்சந்தவகயன மயற்சக்கம் கழத்தநர த்தஎனக்க...

# %%
df_filtered = df_filtered.sample(n=7000)

# %%
print(df_filtered.iloc[0]['text'])
# Out:
# இங்கச ர்ந்தமழப கப்படம எடத்தப்பதமக்கயம் இல்லய

# %%
df_filtered = df_filtered.reset_index(drop=True)

# %%
df_filtered.head()
# Out:
#                                                 text
# 0       இங்கச ர்ந்தமழப கப்படம எடத்தப்பதமக்கயம் இல்லய
# 1  ஆண்ட உனக்கபதத இல்ல ஆனல்நீ இம்மறகற்றஞ்சட்டப்பட்...
# 2         பர்களம்தயர் எல்லரம்தய ர் கபத்தல்கந்தளக்கம்
# 3     அவர் எங்களடன்பணயற்றத்தடங்கம்பதஅவர்கள்சய்வர்கள்
# 4  நான் நாளை ஒரு சிகிச்சை வேண்டும் நீங்கள் அதை செ...

# %%
from PIL import Image, ImageDraw, ImageFont

# %%
def generate_images_with_proportional_fonts(df, font_paths, image_dir="images"):
    """
    Generates images from text records in a DataFrame, distributing the use of
    multiple fonts proportionally, with improved image quality and centered text
    using a fraction of image height.

    Args:
        df (pd.DataFrame): DataFrame containing the text data in a 'text' column.
        font_paths (list): List of paths to the font files (TTF or OTF).
        image_dir (str): Directory to save the generated images.
    """
    num_fonts = len(font_paths)
    num_records = len(df)

    if num_fonts == 0:
        print("Error: No font paths provided.")
        return

    # Calculate proportional distribution of records per font
    records_per_font = [num_records // num_fonts] * num_fonts
    remaining_records = num_records % num_fonts
    for i in range(remaining_records):
        records_per_font[i] += 1

    print(f"Records per font: {records_per_font}")

    font_index = 0
    record_count = 0

    for index, row in df.iterrows():
        tamil_text = row['text']
        print(tamil_text)
        font_path = font_paths[font_index]
        image_path = f"/content/drive/MyDrive/{image_dir}/tamil_image_{index}.png"

        try:
            # Load the font with a larger size
            font = ImageFont.truetype(font_path, size=80, layout_engine=ImageFont.Layout.RAQM)
            # break

            # Create a dummy image and drawing context
            dummy_image = Image.new("RGB", (1, 1), "white")
            draw = ImageDraw.Draw(dummy_image)

            # Get the text bounding box
            bbox = draw.textbbox((0, 0), tamil_text, font=font)
            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # Calculate image size with margin
            image_width = int(text_width * 1.3)
            image_height = int(text_height * 1.3)
            image = Image.new("RGB", (image_width, image_height), "white")
            draw = ImageDraw.Draw(image)

            # Calculate text position using a fraction of image height
            x = (image_width - text_width) / 2
            y = (image_height - text_height) / 2 - (text_height * 0.05) #  Adjusted vertical positioning

            # if font_index == 0:
            #   y =

            # Draw the text
            draw.text(
                (x + text_width / 2, y + text_height / 2),
                tamil_text,
                fill="black",
                font=font,
                direction=None,
                anchor="mm"   # Use 'lt' (left-top) anchor for consistent positioning
            )

            # Save the image as PNG
            image.save(image_path, format="PNG")
            print(f"Image saved to {image_path} with font {font_path}")

        except FileNotFoundError:
            print(f"Error: Font file not found at {font_path}")
        except Exception as e:
            print(f"An error occurred: {e}")

        record_count += 1
        if record_count >= records_per_font[font_index]:
            record_count = 0
            font_index = (font_index + 1) % num_fonts

# %%
font_paths = [
    "/content/drive/MyDrive/fonts/Hind_Madurai/HindMadurai-Regular.ttf",
    "/content/drive/MyDrive/fonts/Noto_Serif_Tamil/NotoSerifTamil_Condensed-Regular.ttf",
    "/content/drive/MyDrive/fonts/Kavivanar/Kavivanar-Regular.ttf",
    "/content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf",
    "/content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf",
    "/content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf",
]

# %%
generate_images_with_proportional_fonts(df_filtered, font_paths, image_dir="Text_images")
# Out:
# Streaming output truncated to the last 5000 lines.
# எனக்கநரக்கமனசலர் அந கமகஇத இயல்பனநடத்தஇல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4500.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஒரஒரபரத பமனவஷயம்என்னன்ன அத பர்க்கந மஅங்கஇரக்கமடயததத ன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4501.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீ மரத்தவத்தற்கமகச் சறந்த பங்களப்பசய்தரக்கறய்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4502.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நன் நீங்கள் சந்தஷமகஇரக்கறீர்கள்எனநம்ப கற ம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4503.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இந்த வகயனவர்த்தகங்கள்மற்றலம்கள்வக்க ரயவஅல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4504.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ட ம்கஸ்டவஸ்பத்தகத்தல் கப்பலல்நடந்ததப்பலஉணரவண்டம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4505.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நம் பல்லயர்தற யல்அவள்பணபரந்தத உனக்கத ரந்தரக்கம
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4506.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இப்பத என்றல்நம்எந்தஜன் கசட்டங்கள ன் பதமழவதம்வரம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4507.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அதற்ககஎன்உய லல்அவனக்க பங்கதரமல்இரக்கமட்டன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4508.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நன்ஒரமக்கயமனவஷயத்தப்பற்றஎழதறன் அதப்பத்தஉங்ககட்டஇப்பவ பசணம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4509.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நன்எல்லவற்றயம்கட்கவ ரம்பக றன் த டரகன்களன்நடனம் நன் தரம்ப வந்தவடன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4510.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நங்கள்க ழந்தகளகஇரந்தபதஇதபன்றவஷயங்கள் இரந்தரக்கவண்டம்என்றநன்வரம்ப கறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4511.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஒரச லமண நரம் அதபவத ல்ல ஒரவ த்தயசத்தஉண்டக்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4512.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இந்த கரயலரந்தமக்கள் வழந்தல் அவர்கள்இறந்தவடவர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4513.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# மலம் கண்ணக்கதரயம் வதமன ஆக்கரமப்பபற்றநன்பசவல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4514.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# மற்றம்ஆர்யபரந்தகள்கறர் ஏன் அவர் அதச ய்தர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4515.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# எலக்ட்ரனக்ஸ்மயத்தன்நக்கத்தற்ககபல்சய்யப்பட்ட ஏக்கர்நலம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4516.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஒரக தயஅடக்கநச்சயமனவழ அவன சதந்தரம்அட ந்தவட்டதகநம்பவப்பததன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4517.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அடத்தந ளக்கநங்கள்எல்லம் தட்டமட்டவத்தரந்தம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4518.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# எதபற்றயம்நீகற சல்லஉனக்கஎப்பட தகதஇர க்கன்னஎனக்க ப்பரயல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4519.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஒரப தநகழ்ச்சதயரப்ப ளர்கரடவட் கல்ட்பர்க் அந்தகஸ்டங்நர்வக யடம் சன்னர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4520.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஒரவன்ந யயப்பரமணம்மழவதய ம் கக்கண்டரந்தம் ஒன்றல தவறனல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4521.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இந்த நகரத்ததன்வீடகமற்ற வதற்கக பத உலகத்தக்கடந்தவந்தள்ளவழகட்டஇரக்கறர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4522.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அடத்தஒரமணந ரத்தக்கடந்தல்உன்னல் ஒரஃபன்டன்பனகடதறக்கமடய ம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4523.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் இங்கரக்கறீர்கள்என்ற என்னல்நம்பவமடயவல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4524.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஒரஇரவல்நயஆர்லயன்ஸப்பதகக்கம் மதகஅமப்பல்இரண்டல்உடப்பஏற்பட்டன
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4525.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நன்உங்களடன்இரக்கவண்டம்என்பதஎனக்கமன்பத ரயம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4526.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவர்களதஅனபவம்பற்ற அவர்களடம்க ட்கவர ம்பகறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4527.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் சல்லநனக்கறன் உண்மநீங்கள்பர யசய்க றத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4528.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அதஒரகப்பகத்தலரந்ததத்தடத்த அவ களம்பயஅன்றஅதஎன்அலவலகத்தல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4529.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# தமழல் சர ச்சக்கண்டஎல்லரம் சர்ந்தஅண்ணனகன்ன ட்டங்களட
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4530.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இந்த உலகத்தல்எதவதஒரமற்றத்த நகழ்த்தவ ண்டம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4531.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இப்பதஅந்தஇழய ல் நம்ம வரம்இரப்பதகநனக்கற ன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4532.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நன்உங்கள்வயதஇரந்தபத நன் உறதப்படகள்உட த்தவட்டம்என்ற
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4533.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அந்த அயக்கயன்என்னஏமற்றமல் இரந்தரந்தல் தசயத லக்கட்சயல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4534.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நச்சயமஅத லகண்டஇரக்கல ஆனல்வ ண்டயவடமரந்தஇரந்தத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4535.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அங்கந ன்மட்டம்தனயக இல்லஎன தரந்ததம் எனக்கஏற்பட்டஅத ர்ச்சஉங்களக்கபரயம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4536.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# மன்பணம்வ ங்கயதம் ஆறம தவல சய்வதகச்சன்னீர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4537.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஆனல்ஓலமன்தன்இதஎவ்வ ற சயல்படத்தவதஎன்பதகண்டறந்தன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4538.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவள் மகவம்மசமனவள் நீங்கள் இரக்கம டயம்இடத்தல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4539.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# பல்ட்க ண்டபத்ஆர்க்கல்ஒரசக்தயக் கண்டசல்கற ர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4540.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவர் பற்றஎதவம்தரயத என்பதல் எங்களக்க அத அவரதமடவநன்சல்கறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4541.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் கஞ்சம்ம சமனவர் உங்கள்அப்ப வக்கஎதரகஒரவ ளநட்டவரடன் கம்பல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4542.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவர்களல்ம ன்றவளப்படயனகளர்ச்சய ஏற்படத்தஉள்ளன
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4543.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவளடயஇதயத்தநீங்கள்என்னடம்கண்டவரவ ண்டம்என்ற நன்வரம்ப கறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4544.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# தளபதயனஜனரல்ஆம்ப்ரஸ்பர்ன்ச ட் என்பவரதப யர்வக்கப்பட்டத சரய
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4545.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஐய இந்தஇடத்தஎன்அளவற்க வறப்பவர்கள்யர்யரனத டப்பக றன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4546.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்க அத எரச்சட்ட அதச ம்பலமறடம் அத மறபடயம்எடக்கமடயத இல்லய
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4547.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நம்ம சீட்டப ட்டவங்களக்கஇர மடங்கத கயககடத்தரவம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4548.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# எனவஒரதப்பக்கபசமனநலச லபண்டக்கலஎச்சங்களகண்கறர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4549.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஆனஅவங்ககபத்தடஎன்னட ரலரந்த வமனநல யம்ஓடபத யல்நீக்கனங்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4550.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இங்கஎன்னஇடர்என்றஎனக்க த் தளவகத்தரய வண்டம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4551.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நான் வரை கொடுக்க வேண்டும் சில நஷ்டம் இல்லை
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4552.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அந்தப் பகதயன்நன் வஷயம்இல்லஅவன்சய்ததம் உதவமடயவல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4553.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நன்ஒரதய் ஆனதப ல்உணர்கறன் நீங்கள் எனக்கஏற்றதஇல்லஎன்ற
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4554.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# மனிதர்களை ஒன்று திரட்டுவது கடினம் அவர்கள் தங்கள் உயிரையும்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4555.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# வளயடவர்கள் ஆனல்ய ரம்எத ர்பரத இடத்தல்மீட்ஃபீல்டல்வளய டவர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4556.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# சஷஹரகடத்தகரமம்மன்றன் கட்சபத வமற்ற ம்தனநபர்பணப்ப
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4557.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அதகஎண்ணக்கயலனதீயணப்ப படயயம் அம்பலன்சயம்கப்படங்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4558.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஆனல்இப்பத நன்ஒரநரகத்தகட க்கறன் நன்ந னக்கறன்வடநறய நறய
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4559.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் ஆறப ட்டக்கப்பறக கவட்டரந்தல்என்னவ கயரக்கம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4560.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# தரயஷ்மற்றம்சமத் அவர்கள் என் சகதரர்களயம்இரந்தர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4561.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நன்உங்களடன்எவர டனம்தடர்ப கள்ளவரம்பகறன் உங்கள் கறஸ்தவபயர்கள்ஒரவர க்கரவர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4562.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# வீட்டல்இரப்பவர்களக்கஏதனம் சல்ல வரம்பகறீர்கள மசஸ்வ ல்சன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4563.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# சர இதவரநன்ச ல்லம டயம் நீங்கள் சல்லநல்லஇர க்கம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4564.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# யர்ம தவகஆனல் அவர்களன்எல்லபட்டகளலம் வற்றபறகறர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4565.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# பனப்பர்கலத்தல்பலஉளவ பர்க்கம்தட்டங்களவழ நடத்தனர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4566.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் உங்கள் கதஒன்றக நீங்கள் பசவதபய்வட்டத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4567.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# கடம்பமத ப்பள்ளஎந்தப்பண்ணம் இப்படச்ச ல்லமட்டர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4568.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நன்ப சநன க்கம்பதல்ல ம் உன் ஞபகம்த ன்வர கறத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4569.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# என் கழந்தகள்மற்றம்உன்அப்பவ வட்டவந்ததகடனமக உள்ளத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4570.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# உங்களக்ககட தம்எழத உங்கள வரச்சல்ல சலந ட்களகஎன்னக்கஞ்சக றள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4571.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அதஎன்வழ யல்தரம்பவரவதபர்த்தல் உங்களடமதர ப்பஅனப்ப வன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4572.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இந்த அறவபம யன்இரண்ட மலகளக்ககண்ட சல்வீர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4573.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# மற்றம்கட்டப்பட்டயம் என்னடம்ஒப்படத்தவட்டர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4574.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# வக்கீல் ஆகஅடத்தவங்கபரச்சனல பணம் சம்பதக்கநன்வரம்பல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4575.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ந ன்தன்நன்வரபடம் என்பதநீங்கள்அற ந்தகள்ள வண்டம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4576.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# மீட்டரவக்கம்சய்வதபறத்தவர இன்னம்ந றயமம்படவண்டம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4577.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இப்படப்பட்டவ ர்த்தகள நன்அவரடமரந்தஎதர்பர்க்கறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4578.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இனஉங்களப்பதக க்க கர்பச்சவ்மற்றம்அவரதக ட்டளகள்இல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4579.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஹம்மண்ட் மஇரவர ம்ஏன்ரங்க்ளர்ஸ ஒரஓரனவடவமகப்பர்க்க றர்கள்என
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4580.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அந்த நசமப்பன இயக்கத்தனல்நன் என் தழல்மறவழ்க்கயயநசம்சய்தன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4581.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவர் சலத்தபத அதனல் அவர்என்னபயன்படத்த மடயம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4582.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# என் பலயல்வழ்க்கயல்இதபன்ற சயலல்ஆர்வம்கட்டயதற்கநன்ற
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4583.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இப்பத இந்தமனதன்கற்றச்சட்டன்பரல்தடப்பட்ட நப்ரஸ்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4584.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# எங்கள் ஆதரங்களன்பட பட்டட் ஐரப்பயஒன்றயபரதந தயடஜஎஸ்இ யஅல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4585.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# வவரம் ட்ரவ்அடய ளங்கள் பத தட்டங்களஆவசரலவக்கஅனப்பனம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4586.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# கள்ளர்கள்நடவலஇரக்கறததனஅதக்க சறந்தவழ இல்லய
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4587.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஆனால் துண்டு கற்கள் அந்த நாள் ஒரு புத்தகம் இருந்தது
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4588.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஒரபதம்அவரக்கஒரகவளயல்எப்பதம்கடப்பத ல்ல எப்பத ம்ஒரபட்டல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4589.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஒரச றந்தகண்டபடப்பளர்ஒரபதம்த ரமணம்சய்த கள்ளக்கட த
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4590.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவர்கள் என்னகண்டபடத்தல் அவர்கள்என்னகயப்படத்த வர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4591.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நர்சகளக்க அவர்கள்என்ன சய்க றர்கள்எனத்தரய ம் டயர்டர
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4592.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அதற்கந ன்வர வல்வரத்தப்படவன் என்றசந்தகக்கறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4593.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# உலகலயமகப்பரயகளப்பகநம்ம ஆக்கவததன்என்ன டயஒரகறக்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4594.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இப்பதக்கஇவ்ளதன்சல்லமட யம் ஆனல்த ரயப்படத்தவன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4595.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் இங்கஎன்னஅழத்த நன்என் அளவீடகள் ஒரஒப்பக்க ள்க றீர்கள்எனஎன்றசல்கறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4596.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# மசஸ்ஃபரஞ்ச் லயனர்ட்வல்தரமணமகதவர்என்றநனத்தர்இல்லய
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4597.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# டட்ல ஸ்ஸஇந்தசீசன ன்டட்டன்ஹம் கமன்நட வவளயற யத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4598.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவர் இரணவவம னப்படயன்மம்பட்ட ரடர்அம ப்பல்பணயற்றனர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4599.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவள் என்ன சய்தள் என்மதக ல இந்த இடத்தலஒரகத்தகத்தன
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4600.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இப்பதநன்நறத்தவளவகள்ஏற்படத்தம்மற்றம்நீங்கள்ந னக்கம்ப த
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4601.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# கவன் என்னஇப்ப தசய்யப்ப கறன்வர்த்தகத்தல் பட்டஅனமதக்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4602.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# எனவ ப ரம்பலம் அவன்இந்தபச னஸன் உரமயளர்என்பதஅப்பட யதக்கவச்சப்பன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4603.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஒவ்வரநய ளயன்இங்கவண்டம் இரக்கஆபத்தனகரதப்படகறத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4604.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# மீதயரக்கறஎன்வ ழ்ந ளல்சஞ்ச தப்ப சரசய்யகழ ப்பன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4605.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவங்க உண்மயவஎல்லத்தயம் சல்லட்டங்கன்னநீநன க்கறய
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4606.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நன்ஒரவறத்தகழயசம க்கவல்லஎன்றல் மக்கள் என்ன சப்படப்பக றர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4607.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் உங்கள் அசங்கமனவய மடப் பகறீர்கள்அல்லதநங்கள்உங்களக்ககஅதம டப்பகறம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4608.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் அனவரம்வள யசன்ற சர்ந்தஏத வதசய்ய ங்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4609.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# டமர்ஸல் எதர்கலத்தப்பற்ற கணப்பகள்பற்றபசஇங்கவரவல்லஎன்றய்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4610.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஏன் அவர் எந்த பரச்சனயம்இல்லஎன்றச ல்கறீர்கள
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4611.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# மன்னதக அல க்சண்டர்பன்றவர்கள்உலகஆளப ர்கள நடத்தனர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4612.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# வடக்கப்பக்கமஇரக்கறசவத்தல ஜன்னலக்கவள யஇரக்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4613.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் நன்றகஇரக்கறீர்கள் நீங்கள்நன்றக இரக்கறீர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4614.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அல்லதந ன்கடவள்சத்த யமக நன்நீங்கள்அன த்தகீழ உறவனர்களன்அல்லதஎந்தக்கடம்பஎடக்கம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4615.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இந்த வழக்கல்இரந்தஅவர வளயற்றநீங்கவரம்பறீங்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4616.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# என் கழந்தபத்தரமகஇரக்க இததவ என்றல் ந ன்அப்படயசய்கற ன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4617.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் வள்ப ரக்கக இன்னம்பயற்சசய்க றீர்கள
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4618.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவர் அக்கறக ட்டயதகழந்தக்கத்தன் சபத்தக்கஅல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4619.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# கவலப்படத ஒரயசனஇரக்க இன்றஅங்கபகவ ய்ப்பரக்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4620.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் அனத்தமற்றவற்றவடமல ம்ப ர்க்கவ ரம்பகறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4621.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அதனல்த ன்ஒர ரஜமட்டமஇரக்கவண்ட ம்என்ற என்தந்தஉழத்தர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4622.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இந்தக் கலவயன்அர்த்தம் உங்கள் கலஅழ த்தஓட்ட ம்வதத்த ல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4623.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# எனக்கவ றவல கடக்கம் ஆனல்ந ன்அப்பவம்இப்பவம்வரந்தற ன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4624.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# எனக்கச ன்னவயசலரந்தமடவ எடக்கறதங்கறதரம்பகஷ்டம னவஷயம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4625.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# தகதபற நரம்கடந்த லம்தனக்கஎத வத வலவண்டம்என்றஆர்வத்த டன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4626.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# பரசல்எப்படஉணர்க றதஎன்பதஎனக்கத்தர யம் வீட்டதரமீதசண்ட
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4627.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# உன் அப்பஎன்னடம்ஹமங்வவசனத்த மற்களகக்கறவ ர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4628.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# என்ன வண்டமன்றலம்சய்யங்கள் எந்த சீக்கன்தலப்பகயம்எடக்கதீங்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4629.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# எனக்கஎதரகப்பட்ட யட்டமக்கள் நன்க ழகளல்பரடய பத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4630.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அதச ய்யம்பததவர நீங்கள் களர்ச்சயகஇரக்கறீர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4631.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# பன்னீர்னந னச்சண்டகஞ்சம் பன்றக்கறயசப்ப ட்டட்டன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4632.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்களம்சரயனநரத்தல்உணவசப்ப டகறீர்கள் என்னப்பற்றகவல ப்படவண்டம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4633.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் ஏமற்றப்பட்டரந்தன்நனத்தல்நன்வரந்த கறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4634.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# எப்பதம்அவளகடந்தஎல்லரம் அவர் கலசய்யஒரவழ யக் கண்டபடத்தர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4635.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# சப்பர்ஹீரக்கள்தர ம்சகம னஉணர்ச்சய மக்கள் மகவம்வர ம்பகன்றனர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4636.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# தப்பக்கயஉங்களக்ககயளத்தர யத நீங்க எங்களபயமறத்தறீங்கள
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4637.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# சபஸ்டயன்லஞ்ச் மன்னள்ரணவம் மற்றம்ர ணவஉளவ த்தற
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4638.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# கருந்துளையில் இருந்து என்னால் சில தகவல்களை பெற முடிந்தது
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4639.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# தரயல்இர ந்தசகரட்எடப்பதந ன் தவறகந னக்கவல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4640.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# எனக்கம ன்பரந்தஅதகர கள் ஆண்டகளல்சம ளத்ததவட
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4641.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இதஎன்இற தஅதர்ஷ்டம்தன்நன் மடவட யம் நரப்பவணக்கத்தரக்கண்டகழ
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4642.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஷகல்டன்பள்ளம்அமர க்கவன்மதல்லனர்தளமக இரக்கல ம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4643.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவள் சறயதகஇரந்தளம் ஆனல்ம ர்க்கத்தனம்கண்டவள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4644.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நங்கள்கற்கள்மட த்தவட்டீர்கள்மறஏனனல் நங்கள் அதன் சந்தடம்லனலம்ஒவ்வரஒர தரம்பமடய ம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4645.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# மற்றும் எக்ஸ்ரே இயந்திரங்கள் மற்றும் கேமராக்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4646.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# கர்உன்னஅவள டம்அழத்தச்சல்லம்வகயல் அமக்கப்பட்டள்ளத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4647.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# எண் இந்த சறவர்கள்தங்கள்வழய ல் சயன்ட்ஆண்ட்ரஸக்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4648.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ஆனல்நமக்கள்ஒரஇணப்ப இரந்தத நம் இரவரக்கம்தரந்தரந்தத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4649.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# மணமகனமீட்கஉங்கள்சகதரரடன்நீங்கள்பயணம்சய்யவண்ட ம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4650.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவர்கள் வந்தஉங்களதனப்பட்டமறயல் சந்தக்கறீர்கள
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4651.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# இப்பத ஆனல்நீங்கள்நம்பக்கஇழந்தல் நீங்கள்இறக்கபகறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4652.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அம்மஎதக்கடம்ம அத்த வீட்டக்கரண்டமசம்ப னங்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4653.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அவரதமனநலயப்பறத்த வரயல் எங்கள் மனநலயப்பறத்தவரயல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4654.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்களம்ஹீலயஸம்ஏதஒப்பந்தம்சய்ததக கமண்டர்ப ல்சல்கறர
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4655.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# அப்படகீழ்நக்கநஞ்ச லகத்தறத ங்கறதகஞ்சம்மரணஇர க்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4656.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நமக்கு எரிபொருள் சிறிது வீணாகினாலும் அதிக நேரத்தை சேமித்திருப்போம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4657.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்க சன்னம தரகம்ப பயன்படத்த ஆப்பரக்கசரக்கதயர்பண்ணங்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4658.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் அறவீர்கள்என்றஉங்களக்கத்தரயம் உயரடசப்பட
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4659.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# என் உலகம் வளயகத்தரக்கறதஅவனததயர்அவனபள்ள யலரந்த அழத்தச்சல்வதற்கக
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4660.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# ரவல் என்னடயமகளன் மதல்சம்பத்தய நகழ்ச்சக்க இதஎனக்க த்தவ
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4661.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# டவல்உண்மயனஎன்றல் கடவள்உண்மயன மக இரக்கவண்ட ம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4662.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் அவர்களன்வ சவசத்தவரம்ப கறீர்கள் நீங்கள் அதசம்பதக்கவண்ட ம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4663.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் உயரடதன் உள்ளீர்கள்என எப்பதம்நன த்தன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4664.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நமடத்தக்கஒரமற தடவ கய்ந்த பகமல்பர்த்தக்கள்வத மகஅவசயம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4665.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# வீடயவபர்க்கம்பததரஞ்சதஎவ்ள எக்சட்டங்கஇரந்தரக்கன்னசல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4666.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# நீங்கள் இரவரம்அவரதமனவமீதஅழத்தம்கட த்தீர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4667.png with font /content/drive/MyDrive/fonts/Noto_Sans_Tamil/NotoSansTamil-VariableFont_wdth,wght.ttf
# என் கண்களல்எம்ப்ரய்டரசய்யப்பட்டஅந்தநட்சத்த ரங்களப்பல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4668.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# எனக்கஒரகப்பயம் ஒரஆப்பள் பயம்ஃபீப்பம்பர்சல்தரமடயம
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4669.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# இன்றந ங்கள்படகபயணம்சய்கற ம் வரம்பனல்நீவரலம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4670.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# இதம ட்டள்தனம் நீங்களம் எனக்கஇதத்தன்சய்ததகஉணர்கறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4671.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# குறைந்த பட்சம் என் மருதாணி வெளியே மாறுவது வரை
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4672.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# உனக்கமனதல்ஆர்வம்இல்ல ன நீ உயரடஇர ப்பதகஅர்த்தம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4673.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# அறவன்பலனஅனபவ த்தபறக மனதஇனத்தற்கஇரண்டவழகள்த ன்உள்ளன
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4674.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# பரச்சனக்கத்தீர்வகணமடய மல் பலம்பக்கண்டரப்பீர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4675.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# ஒனடகவ ண்ட ஒனண்டககவண்ட ஒன்டறயகவண்ட ஆரஞ்சகவண்ட
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4676.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நீங்கள் கட்கவ ண்டயகள்வகளஉங்களயக ட்டக்கள்ளங்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4677.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# இல்ல ந ன்நீங்கள்நன்றகஇரக்க வரம்பக றன்நனக்கறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4678.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நீங்கள் தரம்பவந்ததல்அந்தப ண்கள்உயரடன்இரக்கறர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4679.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நன்க ரசனச்சர்ந்தசறவர்களக்கமழகவர்த்தஏற்றகறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4680.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# உங்கள் பக்கம் கடசநம டத்தல் எந்த மற்றமம்இர க்கதல்லவ
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4681.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# ஆக உன் அக்கச ன்னதசரஎன்பத ல் வரந்தகறயஅல்லத தவறஎன்பதல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4682.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# இந்த மதக்கட்டத்தசர்ந்த எவரம்எவரயம்மீட்டதகநன்நம்பவல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4683.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# கற க்கீடசய்யந ன்வரந்தகறன் ஆனல்என்தட்டல்என்ன சய்ய வண்டம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4684.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நீங்கள் டஸ்மற்றம்பழத கடத்தவ ட்டத டஸ்மற்றம்பழத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4685.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# பரங்கள் அவர்கள்நரகரக்கப்பட்டல் நன்என்வல யஉறஞ்சவன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4686.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நீங்கள் ஒரவ ளஆலசகரகஎன்னஊத யத்தல்வத்தரக்கறீர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4687.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# வயலன்ஸ் நம்ம வீட்டக்கவர ம்பதத ன் அதடவலஎன்னன்னநமக்கத்தரயம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4688.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நீங்கள் ஆம்ஸ்டர்டமல்உள்ளஒரத ரயரங்கற்கள்நழந்தஒரபீர்வங்கலம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4689.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# இப்பதபய்இந்த உடயம ற்றக்கண்ட நீச்சல் களத்தரகஎன்னவந்தப ர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4690.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# பரங்கள் கலயல்கற ந்ததஒரமண நரம் நங்கள்அனவரம்மடயல்இரந்தம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4691.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நங்கள்எங்கள்வர களபன்ன ல்பரளகள் அனமதக்கமடய த
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4692.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# பத்தயக்கரத்தனமஅததட அலஞ்ச நறயரண வத்தஇழந்த ரக்கங்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4693.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நடவர நமஏன்இந்தவழக்கவசரணயதரம்ப நடத்தசல்லக்கடத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4694.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# சறமயபலயல்வன்கடம சய்தஅமச்சரநயயப்படத்தகறீர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4695.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நீங்கள் அவளந ற்கமட யத உங்களக்கபரச்சனகள் உள்ளன
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4696.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# அன்றரவஅந்தவளகத்தல்ஒரகர்ச ற்ற க் கண்டரந்ததகஅக்கம்பக்கத்தனர்கறனர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4697.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# ஆனல்அதஒரஇயற்க வஷயம் இரண்டசற வர்கள் ஒரபயணத்தன் கண்ட
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4698.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# ஆனஅவதப்பச்சட்டளம் அதனலஅவங்க கதவஎண்இரண்டதர்ந்தடக்கறங்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4699.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# ரண்டபட கர்டகள் ரண்டஎண்கர்டகள் அதல்ர ண்டஎட்டஇரக்கணம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4700.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# இல்லை இது புதிய கண்டத்தை கண்டுபிடிப்பதை போன்றது அல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4701.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# எல்லத ழல்நட்பங்களயம்கற்பனச ய்தபரங்கள் இதவரமன தர்கள்உரவ க்கயள்ளனர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4702.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# ஸ்வர்ன இந்தநரத்தல்என்ன கற்றம்ச ட்டவதகவரம்பவல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4703.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# உனக்கஇன்னம்தரந்தநஜம் நீ நஜத்ததடர்ந்தஅறவய்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4704.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நன்ப ரந்தஓட்ட பவர்பல்யச ப்பத ல் எனக்கக றந்தமதப்பண்கள்கடத்தத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4705.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# அவர் அங்கஉயரடஇரக்க றரன்றஎனக்கதரயம் அவர் எனக்கத ரயம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4706.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# இல்ல பற்றர்கள்உனக்கவங்க த்தரம்வல யயர்ந்த கர்களப்பத்தபசலன்ன நீசரப்பட மட்ட
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4707.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# அவர் தக்கலடப்பட்டபன்னர் நன்ம லதனத்தவட்டவளயறனன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4708.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நீங்கள் இங்கஇரப்பதபயல் வரம்பவட்டல் நீங்கள்பகத்தன்வண்டம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4709.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# எங்கள் ஏற்பட்டப்பற்றவறயர க்கத்தரயம் இங்க ஒரப ண்இர ந்ததகயரவத சன்னர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4710.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# கர்மயலக்கஇரமல் சண்டக்க தற்றஏற்படவதநன்வர ம்பவ ல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4711.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# உன்னப்பற்றயம்மட்ச ப்பற்றயம் நன்ய கங்களச்சய்தள்ளன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4712.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# என்ன இங்கம ம்பயலநறய மசமனகயங்கள்ஏற்படம்னஎதர்பர்த்தய
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4713.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# பதஆட்டம்மடந்தநலயல் ஆர்சனலடம்மன்றகல்இர க்கறத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4714.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# உன் கள்ளதத்தபட்ட வர நங்கள்உன்பரம்பரகண்டறந்தம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4715.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நம் தரமணத்தற்கப்பறக நன் உன்னபல்லவயடன்பகர்ந்தகள்ளணம
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4716.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# சம்ரஜ்யத்தற்கஏழரஜ்ஜயங்கள்மற்றம்ப்ர டக்டரன் இறவன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4717.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# சலர் ஆம்பரஸ்தன்க டம்பத்தன் கறம்பள்ளன்னதப்ப பரஞ்ச கட்டரக்கங்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4718.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# அமரக்ககடற்படவடகண்டகப்பலஅணக கழவற்கஉத்தரவட்டீங்கள
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4719.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நன்ந ரங்கமடந்தல் அந்தவடகளல் ஒன்றமறந்தரந்தசடமடயம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4720.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# கச்ச மர்கரசன் நம்ரஹம் மற்றம்ம க்பய்லக்கம்என்நன்றகள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4721.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நீங்கள் கரதகன்றனவஷயங்களநீங்கள்மடயம்என்றஎனக்கதர யத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4722.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# சதனகள்இர ந்தல்மலம் சய்தத்தள்அறக்ககள்இர க்கம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4723.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# நீங்க இங்க நறயபரச்சனகள சந்தக்கவ ண்டஇரக்கம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4724.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# அதக லயகஇரந்தலம்கட என்னடம்ப ரமஒன்ற ம்மச்சம்இல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4725.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# பறஎல்லயல்உள்ள நம்ப ர்வ யளர்களன் அறக்ககளசரப ர்த்தன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4726.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# உங்களஅவமனப்படத்தவரம்பகறத ஆனல்நீங்கள்அவர்களஅனமத க்கவட்டல்அதஇயங்கத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_4727.png with font /content/drive/MyDrive/fonts/Pavanam/Pavanam-Regular.ttf
# ...
# அறபதநட களக்கப்பறக தல மயகத்த டனன எல்லத டர்பகளயம்இந்தகட்டடம்இழந்தவட்டத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6923.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# உனக்கம கவம்மக்கயமஇரக்கற சலவ ஷயங்கள்என்னஆகறத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6924.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# இனமல்எங்கள்யரய ம்உன்னடன் பச அவர்அன மதக்கப்பவதல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6925.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# கக்கப்பர்க்கமல்நங்கள்இங்கரந்தபனல் நன்மற்றரமகளர ஸல்ச ர்த்தவ டவன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6926.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# ஆனல்உண்மஎன்னவன்றல் என்வழ்க்க பகம்பத எனக்கப்படக்கவ ல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6927.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# கணவன்களக மனவகளக மகன்களக மற்றம்மகள்களகநனத்தபசகறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6928.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# என் ஆட்களவ ட்டஇங்கவந்தஅவனகவனக்கச் சல்றன் அப்பறம்மரஃஜ சவப்படப்பம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6929.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# சமீபத்தல ர ஜல்ஆடகரட மக்கயமனதரமத்தலஇரந்தன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6930.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# எனதக ல்பந்தஅணய ல் என் இந்தமததழ சஞ்ச இரக்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6931.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# மலம்நீ பட்ரீஷயரய்ட்லரன் பணம்இரக்கம்இடத்தகண்டபட த்தல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6932.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அதனல நீஎங்கயவதமணபரம் சர்ந்த இரக்கலம்னசல்லப்பறயன்னகளம்பட்டன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6933.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# இல்ல இவயனத்தயம்எளயதரவ மலண்மபரச்சனகள்இரப்பதல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6934.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# உங்களக்கதர யம் மலஎங்கஇரக்கறர்என்றநன்உங்களக்கசல்கற ன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6935.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# நீ எத்தனபகதநரதன யர் தப்பறவளர்களபரந்தரத்தய்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6936.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# உங்கள் ஹட்டலக்கசய்யப்படம்மற்றங்களக்கப் பறக வண்கலம்கட்டத்தட்டதனயங்க யகவடம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6937.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# ஒரதனயர்ஒப்பந்ததரர்பயனல் ஒரஅமரக்கதளத்தன்மீத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6938.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# நீங்கள் ஏன் தரயம அவர்கள் வத்தஆக்சஜன்மகமட கள்மீதவமனங்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6939.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# என் அழகனகண்களக்ககநீஎன்னப் பர்க்கவந்ததகநன் எப்படநனத்தன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6940.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# ஒரந ன்நச்சயமகநன்வய்ப்பக டத்ததஎன்றல்அவரதமளவ ளயஃபக்எப்பட
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6941.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# நீ உன் கடம்பவழ்க்கயஎப்படப டவதம நசமக்கறஎன்பதபற்றப சவம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6942.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# நங்கள்இந்தரஜதந்தரசம்பவத்தற்க பறப்பற்கமடய த
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6943.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# நன்ச ஷயல்மீட யவபர்த்த ல் கரப்பஓட்டக்கள்பய்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6944.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# இட்டச்ச எத ரயன்எண்மற்றம் அவற்றன் அம்சங்கள ப்பற்றசல்லங்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6945.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# என் சகதரமற்றம்நன்எல்லவற்றயம்பதலம் ஒரவரஒரவர்நசத்தனர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6946.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# இவ்வளவநீண்டகலத்தற்கஅவர்கள்என்உண்ம யனப யர்ஞபகம் இல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6947.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# சர் வ யதமலவ ய்த பட்டவய்ல நரதள்ளவரஷங்கள்பலஉரண்டட
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6948.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# எங்கள் ஊழயர்களக்ககப்பீடசம்பந்தமக பல பரச்சனகள்உள்ளன
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6949.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# பல பறவகள்இங்க மீட்கப்பட்டனர் இரந்தகடத்தல்கரர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6950.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# பல்வறநகரங்களச்சர்ந்த நகரவசபத்தரகயளர்களடமரந்த
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6951.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# பறகஇங்கஇரக்கம்பத்தன்ம லம் கணனயமீண்டம்இயக்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6952.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# நன்என்அண களல்கலகரர்கள்நீதசவசய்வதல்லஎன்றல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6953.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அண்ணக கய்ன்கக்கய்ன் எடத்தட்டரக்கதமட்டப்பம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6954.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அதவத நன்தன்ஹ ல்லக்கநட பயற்சதவ ன்னநனத்த ன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6955.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# தங்களன்உண்மயனசக்த யவளஉலகத டம்இரந்தமறத்தனர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6956.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# மன்னடஉட்கர்ந்த நீங்கள் மட்டமகர ப்பபலகப ரங்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6957.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அவர் அந்த வஷயங்களச்சய்தர்என்பத உங்களக்கத்தரயம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6958.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# நனம்உங்களடயதஅல்ல ஆனல்இந்தஇரவஅப்படத்தன்இர க்கவண்டம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6959.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# ஏனனல்உனக்கத்தரந்தரந்தல் நீ எங்களடன்வீட்டக்கவந்த ரப்பய்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6960.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அப்பதஎங்களக்கபக்கத்தல்இரந்தஎன் நண்பன் ஆண்ட்ரஜ ன்சன்வீட்டலரந்தன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6961.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# யர இன்றகல்லப்பட்டர் ஏனனல்நீங்கள்சய்ததஎன்ன
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6962.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# ஐசயவல்நன்கநயளகள் மட்டம அதல்க யழத்தட்டரக்கறர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6963.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# பர அந்தகணன கள்எப்பத ம உள்ளணர்வம் எண்ணங்களம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6964.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# கடக்கறசம்பளத்தவங்க வீட்டலஉட்கர்ந்தடவபர்த்த
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6965.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# உங்க தகவல் சரயஇர ந்த அவங்க இந்த பதவழ யதன்வரணம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6966.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# இந்த வஷயத்தநங்கள்இரகச யமகவத்தரக்க வண்டம்என்றஎன்அம்மச ன்னர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6967.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# நம்கடற்கரயவட்ட வளயறம் மன் லமீன் அம்மவற்கப பசல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6968.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# நீ இன்னம்என் பட்டக லறகளக்ககடன்பட்டரக்கறய்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6969.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அன்றஅவர்உங்களக்கஎன்னச ய்தர் வளயஇல்ல அவரதசீரடயன்ஆணவம் இல்லய
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6970.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# நீ நல்ல பயன்தன பய் அந்த பன்பக்கம்ந ரஇரக்கறநற்கல ய
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6971.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# யலரந்தகடந்த நட்களன்கட்ச களநங்கள்ச கரத்தம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6972.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அவர்களஎங்கவதஅனப்பவண்டம் என்றல் ஒரவகனத்தல் ஏற்றஅனப்பவப்பம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6973.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அவர்கள் அந்த உரமயனஇடத்த கவல்க த்தக்கண்டரக்கறர்கள்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6974.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# இப்பதமல்இரக்கக்கடம் ஆனல்ந ன்இன்னம்உணர்கறன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6975.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# எங்கள் கமம்தீயகஎரந்தத ஆனல் இப்பதபக யத்தவரவற எதவம்இல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6976.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# இப்பதநீ என்னவரம்பகறய் அவர்களக்கஎத ரகபரடவ ண்டம
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6977.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அவர் உங்களத்த க்கனர் பன்னர்அவர் அந்த கரல்மத னர்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6978.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# சர்க்கரர வக்கம்நீங்கள்அதசறந்தஆல சனயவழங்கலம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6979.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# க்ளீஷன் பப்ஒரகளக்கமீண்படக்கம் நளநடத்தறங்க
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6980.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# இல்ல ந ன்ஒர வளர்ந்த பக்கவமல்லத சட்டமண்டயன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6981.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அந்த நஜீரயசற வன்என்ன மகவம்ஆச்சரயப்படவத்த வட்டன்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6982.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# எல்லமமன்பபலவநடக்கம் என்பதமக்கள்அற ந்தகள்ள வண்டம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6983.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# எங்கள்நம்பக்க நீங்கள ம்சர்வகஇர க்கறீர்கள் இல்லய
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6984.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# வறஎந்தமனதன ம்நனம் நீங்கள் சயல்படத்தவண்டம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6985.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அதகபட்சமக இவ்வளவதரம்த ன்உலக வர்த்தக மயத்தன்அட தளத்தநரங்கமடயம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6986.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# இந்த நளலரந்தஒரத்தர்மன்கலத்தடன் தடர்பகண்டல்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6987.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# உங்களக்கதர யம்கஸ்பட ப்பகள் என் தலயல்இர ந்தகல்வர
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6988.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# மற்ற கஏக்கள்இரந்தல் அதல்லம்அவகட்டவசரக்கணம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6989.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அவர்களன்மறப்பல்நன்வ ளயற்றப் பட்டபதஇங்கரந்தஅழப்பவந்தத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6990.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# நன்அவர்நன க்கவல்லபகறர் இரக்கபதல்என்றதலபச தணய
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6991.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# ஜம்மஅப்பட்டமனபறவஓட்டனர் அவர் எதயமநனப்பதல்ல
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6992.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அனப்பப்பட்டஎல்லரம் அந்த அழப்பகள்இறந்தவட்டன
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6993.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# சலந ரங்களல் அதநீங்கள்என்னடன்இரக்கறம் பல வறம்நீங்கள்கட்ட
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6994.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# இவனக ரக்ககட்ட சல்ல நீ கர்ட்டபயன்படத்தக்கள்ளலம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6995.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# உங்க எல்லரக்கம்பறந்தநளக்கண்டடஇந்த பயனடன்பர ம்தட்டம்இரக்க தரயம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6996.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# உங்கள் அம்மஇன்னம்இரக்கவண்டம் நீங்கள் வடபயங்கரமன
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6997.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# ஒரவளநன் சட்ச கறம்பழ த கலநடந்தநரம் அவன் என்னடவீட்டல்இல்ல என்றம்
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6998.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf
# அவர் என்னக லசய்யம்படகஞ்சனர் அவர ஆனல்நன் மடயத
# Image saved to /content/drive/MyDrive/Text_images/tamil_image_6999.png with font /content/drive/MyDrive/fonts/Anek_Tamil/AnekTamil-VariableFont_wdth,wght.ttf

# %%
from datasets import Dataset, Image
from PIL import Image as PIL_Image
import os

# %%
def create_huggingface_dataset(df, image_dir, dataset_name="tamil_text_images"):
    """
    Creates a Hugging Face dataset from a pandas DataFrame and corresponding images.

    Args:
        df (pd.DataFrame): DataFrame containing the text data in a 'text' column.
        image_dir (str): Directory where the images are stored.
        dataset_name (str, optional): Name of the Hugging Face dataset.
            Defaults to "tamil_text_images".

    Returns:
        datasets.Dataset: The created Hugging Face dataset, or None on error.
    """
    images = []
    texts = []
    image_paths = []

    for index, row in df.iterrows():
        tamil_text = row['text']
        image_path = os.path.join(image_dir, f"tamil_image_{index}.png")

        if not os.path.exists(image_path):
            print(f"Warning: Image not found at {image_path}. Skipping.")
            continue

        try:
            # Open the image using PIL
            img = PIL_Image.open(image_path)
            images.append(img)  # Append the PIL Image object
            texts.append(tamil_text)
            image_paths.append(image_path) # keep track of the path
        except Exception as e:
            print(f"Error loading image at {image_path}: {e}. Skipping.")
            continue

    if not images:
        print("Error: No images were successfully loaded.")
        return None

    # Create a dictionary with the data
    data = {
        'image': images,
        'text': texts,
        # 'image_path': image_paths, # Added image paths
    }

    # Create the Hugging Face dataset
    dataset = Dataset.from_dict(data)

    # Convert the 'image' column to the Hugging Face Image feature.
    dataset = dataset.cast_column("image", Image())

    print(f"Dataset created with {len(dataset)} samples.")
    return dataset

# %%
image_dir = "/content/drive/MyDrive/Text_images"

# %%
dataset = create_huggingface_dataset(df_filtered, image_dir)
# Out:
# Dataset created with 7000 samples.

# %%
dataset
# Out:
# Dataset({
#     features: ['image', 'text'],
#     num_rows: 7000
# })

# %%
def save_huggingface_dataset(dataset, save_dir, dataset_name="tamil_synthetic_ocr_f"):
    """
    Saves a Hugging Face dataset.

    Args:
        dataset (datasets.Dataset): The Hugging Face dataset to save.
        save_dir (str): Directory where the dataset should be saved.
        dataset_name (str, optional): Name of the dataset.  Defaults to
            "tamil_text_images".
    """
    try:
        # Save the dataset
        dataset.save_to_disk(os.path.join(save_dir, dataset_name))
        print(f"Dataset saved to {os.path.join(save_dir, dataset_name)}")
    except Exception as e:
        print(f"Error saving dataset: {e}")

# %%
if dataset is not None:
    save_dir = "/content/drive/MyDrive/"  # Replace with the directory where you want to save the dataset
    save_huggingface_dataset(dataset, save_dir)
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/7000 [00:00<?, ? examples/s]
# Dataset saved to /content/drive/MyDrive/tamil_synthetic_ocr_f

# %%
from datasets import load_dataset

# Load the dataset
dataset = load_dataset("Nevidu/tamil_synthetic_ocr")
# Out:
# Generating data split: 7000 examples [00:00, 29087.17 examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     data: Dataset({
#         features: ['image', 'text'],
#         num_rows: 7000
#     })
# })

# %%
# Access the first example
first_example = dataset['data'][0] # Assuming a 'train' split

# Get the image and text
image = first_example['image']
text = first_example['text']

print(f"Text: {text}")
# image.show() # To display the image (requires libraries like Pillow)
# Out:
# Text: பரச்சனகளதீர்த்தவடவம்என்ற நம்பஎங்கள்வண்கலத்தவடவமத்தம்
